# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import datetime as dt
import re

# %%
Data_CM_2017= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_2017.csv', index_col = False, encoding='latin-1', sep = '|', low_memory = False)
Data_CM_2018= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_2018.csv', index_col = False, encoding='latin-1', sep = '|', low_memory = False)
Data_CM_2019= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_2019.csv', index_col = False, encoding='latin-1', sep = '|', low_memory = False)
Data_CM_2020_1= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202001-202007.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Data_CM_2020_2= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202008-202012.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Data_CM_2021_1= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202101-202106.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Data_CM_2021_2= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202107-202109.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Data_CM_2021_3= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202110-202112.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Data_CM_2022_1= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202201-202205.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Data_CM_2022_2= pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\DB_Costo_202206-202212.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)

# %%
Data_CM_2017['MesRad']=Data_CM_2017['ï»¿MesRad']
Data_CM_2018['MesRad']=Data_CM_2018['ï»¿MesRad']
Data_CM_2019['MesRad']=Data_CM_2019['ï»¿MesRad']

# %%
a1, a2, a3, a4, a5 = Data_CM_2017['numrad'].count(), Data_CM_2018['numrad'].count(), Data_CM_2019['numrad'].count(), Data_CM_2020_1['numrad'].count(), Data_CM_2020_2['numrad'].count()
a1, a2, a3, a4, a5
# Out:
# (1771000, 2003838, 2400269, 930810, 821341)

# %%
a6, a7, a8, a9, a10 = Data_CM_2021_1['numrad'].count(), Data_CM_2021_2['numrad'].count(), Data_CM_2021_3['numrad'].count(), Data_CM_2022_1['numrad'].count(), Data_CM_2022_2['numrad'].count()
a6, a7, a8, a9, a10
# Out:
# (1005781, 590474, 591363, 959540, 786176)

# %%
Data_CM_2022_2.dtypes
# Out:
# MesRad                   object
# SucursalContrato         object
# SucursalRad              object
# numrad                    int64
# Factura                  object
# CarnetUsuario            object
# TipoDoc                  object
# Documento                object
# Asegurado                object
# Sexo                     object
# Edad                      int64
# TipoContrato             object
# codmatriz               float64
# RangoEtareo              object
# Area                     object
# CodConcepto              object
# CodServicio              object
# Servicio                 object
# Cantidad                  int64
# MesPrestacion            object
# FechaPrestacion          object
# NAP                      object
# VrFacturado               int64
# GlosaAceptada             int64
# GlosaAplicada             int64
# CostoMedico               int64
# Bonos                     int64
# CostomenosBonos           int64
# TipoIps                  object
# Codips                  float64
# IPS                      object
# CodIPSRemite            float64
# IPSRemite                object
# PlanCosto                object
# NombrePlancosto          object
# Familia Plan             object
# Unidad                   object
# TipoServicio             object
# Ambito                   object
# TipoCosto                object
# PatologiaAC              object
# Dx                       object
# Diagnostico              object
# TipoServicioAgrupado     object
# FechaRadicacion          object
# Tipo Red                 object
# dtype: object

# %%
CM_Total = pd.concat([Data_CM_2017, Data_CM_2018, Data_CM_2019, Data_CM_2020_1, Data_CM_2020_2, Data_CM_2021_1, Data_CM_2021_2, Data_CM_2021_3, Data_CM_2022_1,
                      Data_CM_2022_2], axis = 0, ignore_index = False, keys = None, sort = False, copy = True)

# %%
CM_Total['numrad'].count()
# Out:
# 11860592

# %%
CM_Total
# Out:
#          ï»¿MesRad SucursalContrato    SucursalRad        numrad    Factura  \
# 0       01/01/2017          ARMENIA         BOGOTA  1.701000e+09        534
# 1       01/01/2017          ARMENIA         BOGOTA  1.701000e+09       8335
# 2       01/01/2017          ARMENIA         BOGOTA  1.701000e+09      43430
# 3       01/01/2017          ARMENIA         BOGOTA  1.701000e+09      43430
# 4       01/01/2017          ARMENIA         BOGOTA  1.701000e+09      43430
# ...            ...              ...            ...           ...        ...
# 786171         NaN    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09    FVEL169
# 786172         NaN    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09       1465
# 786173         NaN    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09  FECR16567
# 786174         NaN    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09  FECR16567
# 786175         NaN    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09  FECR16567
#
#        CarnetUsuario TipoDoc   Documento                        Asegurado  \
# 0           31554001      CC    41949763         ANGELA MARIA AYA SANCHEZ
# 1            9983401      CC     4365611      HERNANDO  ESCOBAR JARAMILLO
# 2           31471502      CC    39026074    MARIA NIDIA CEBALLOS DE ARIZA
# 3           31471502      CC    39026074    MARIA NIDIA CEBALLOS DE ARIZA
# 4           31471502      CC    39026074    MARIA NIDIA CEBALLOS DE ARIZA
# ...              ...     ...         ...                              ...
# 786171      42592803      RC  1123088414            VALERIE  SILVA MARTIN
# 786172      40547702      RC  1123449653         FEDERICO  RIVERA CARDONA
# 786173      40508801      CC    52914764  RUTH YUBELLY SARMIENTO CHAPARRO
# 786174      40508801      CC    52914764  RUTH YUBELLY SARMIENTO CHAPARRO
# 786175      40729503      CC    39949444          RUSNEYER  GUTIERREZ ROA
#
#        Sexo  ...  PatologiaAC    Dx                               Diagnostico  \
# 0         F  ...          NaN   NaN                                       NaN
# 1         M  ...          NaN  h270                                   AFAQUIA
# 2         F  ...          NaN  M069      ARTRITIS REUMATOIDE, NO ESPECIFICADA
# 3         F  ...          NaN  M069      ARTRITIS REUMATOIDE, NO ESPECIFICADA
# 4         F  ...          NaN  M069      ARTRITIS REUMATOIDE, NO ESPECIFICADA
# ...     ...  ...          ...   ...                                       ...
# 786171    F  ...          NaN  H109            CONJUNTIVITIS, NO ESPECIFICADA
# 786172    M  ...          NaN  H669             OTITIS MEDIA, NO ESPECIFICADA
# 786173    F  ...          NaN  M545                   LUMBAGO NO ESPECIFICADO
# 786174    F  ...          NaN  M542                               CERVICALGIA
# 786175    F  ...          NaN  K589  SINDROME DEL COLON IRRITABLE SIN DIARREA
#
#          TipoServicioAgrupado      MesRad Usuario Nuevo  RED Tipo Red  \
# 0           Consultas Medicas  01/01/2017           NaN  NaN      NaN
# 1           Consultas Medicas  01/01/2017           NaN  NaN      NaN
# 2                 Laboratorio  01/01/2017           NaN  NaN      NaN
# 3                 Laboratorio  01/01/2017           NaN  NaN      NaN
# 4                 Laboratorio  01/01/2017           NaN  NaN      NaN
# ...                       ...         ...           ...  ...      ...
# 786171            Laboratorio   1/09/2022           NaN  NaN  Externa
# 786172              Reembolso   1/09/2022           NaN  NaN  Externa
# 786173  Imagenes Diagnosticas   1/09/2022           NaN  NaN  Externa
# 786174  Imagenes Diagnosticas   1/09/2022           NaN  NaN  Externa
# 786175  Imagenes Diagnosticas   1/09/2022           NaN  NaN  Externa
#
#         Familia Plan FechaRadicacion
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# ...              ...             ...
# 786171        Azules      16/09/2022
# 786172        Azules      23/09/2022
# 786173        Azules       7/09/2022
# 786174        Azules       7/09/2022
# 786175        Azules       7/09/2022
#
# [11860594 rows x 49 columns]

# %%
df_DC = pd.DataFrame(CM_Total)

# %%
del [[Data_CM_2017, Data_CM_2018, Data_CM_2019, Data_CM_2020_1, Data_CM_2020_2, Data_CM_2021_1, Data_CM_2021_2, Data_CM_2021_3, Data_CM_2022_1, Data_CM_2022_2, CM_Total]]

# %%
df_DC.drop(['ï»¿MesRad', 'Usuario Nuevo', 'RED', 'Tipo Red'], axis=1, inplace=True)

# %%
df_DC
# Out:
#        SucursalContrato    SucursalRad        numrad    Factura CarnetUsuario  \
# 0               ARMENIA         BOGOTA  1.701000e+09        534      31554001
# 1               ARMENIA         BOGOTA  1.701000e+09       8335       9983401
# 2               ARMENIA         BOGOTA  1.701000e+09      43430      31471502
# 3               ARMENIA         BOGOTA  1.701000e+09      43430      31471502
# 4               ARMENIA         BOGOTA  1.701000e+09      43430      31471502
# ...                 ...            ...           ...        ...           ...
# 786171    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09    FVEL169      42592803
# 786172    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09       1465      40547702
# 786173    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09  FECR16567      40508801
# 786174    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09  FECR16567      40508801
# 786175    VILLAVICENCIO  VILLAVICENCIO  4.225004e+09  FECR16567      40729503
#
#        TipoDoc   Documento                        Asegurado Sexo  Edad  ...  \
# 0           CC    41949763         ANGELA MARIA AYA SANCHEZ    F  35.0  ...
# 1           CC     4365611      HERNANDO  ESCOBAR JARAMILLO    M  78.0  ...
# 2           CC    39026074    MARIA NIDIA CEBALLOS DE ARIZA    F  69.0  ...
# 3           CC    39026074    MARIA NIDIA CEBALLOS DE ARIZA    F  69.0  ...
# 4           CC    39026074    MARIA NIDIA CEBALLOS DE ARIZA    F  69.0  ...
# ...        ...         ...                              ...  ...   ...  ...
# 786171      RC  1123088414            VALERIE  SILVA MARTIN    F   4.0  ...
# 786172      RC  1123449653         FEDERICO  RIVERA CARDONA    M   3.0  ...
# 786173      CC    52914764  RUTH YUBELLY SARMIENTO CHAPARRO    F  38.0  ...
# 786174      CC    52914764  RUTH YUBELLY SARMIENTO CHAPARRO    F  38.0  ...
# 786175      CC    39949444          RUSNEYER  GUTIERREZ ROA    F  46.0  ...
#
#                  TipoServicio       Ambito TipoCosto PatologiaAC    Dx  \
# 0           Consultas Medicas  Ambulatorio       NaN         NaN   NaN
# 1           Consultas Medicas  Ambulatorio       NaN         NaN  h270
# 2                 Laboratorio  Ambulatorio       NaN         NaN  M069
# 3                 Laboratorio  Ambulatorio       NaN         NaN  M069
# 4                 Laboratorio  Ambulatorio       NaN         NaN  M069
# ...                       ...          ...       ...         ...   ...
# 786171            Laboratorio  Ambulatorio       NaN         NaN  H109
# 786172              Reembolso   Reembolsos       NaN         NaN  H669
# 786173  Imagenes Diagnosticas  Ambulatorio       NaN         NaN  M545
# 786174  Imagenes Diagnosticas  Ambulatorio       NaN         NaN  M542
# 786175  Imagenes Diagnosticas  Ambulatorio       NaN         NaN  K589
#
#                                      Diagnostico   TipoServicioAgrupado  \
# 0                                            NaN      Consultas Medicas
# 1                                        AFAQUIA      Consultas Medicas
# 2           ARTRITIS REUMATOIDE, NO ESPECIFICADA            Laboratorio
# 3           ARTRITIS REUMATOIDE, NO ESPECIFICADA            Laboratorio
# 4           ARTRITIS REUMATOIDE, NO ESPECIFICADA            Laboratorio
# ...                                          ...                    ...
# 786171            CONJUNTIVITIS, NO ESPECIFICADA            Laboratorio
# 786172             OTITIS MEDIA, NO ESPECIFICADA              Reembolso
# 786173                   LUMBAGO NO ESPECIFICADO  Imagenes Diagnosticas
# 786174                               CERVICALGIA  Imagenes Diagnosticas
# 786175  SINDROME DEL COLON IRRITABLE SIN DIARREA  Imagenes Diagnosticas
#
#             MesRad Familia Plan FechaRadicacion
# 0       01/01/2017          NaN             NaN
# 1       01/01/2017          NaN             NaN
# 2       01/01/2017          NaN             NaN
# 3       01/01/2017          NaN             NaN
# 4       01/01/2017          NaN             NaN
# ...            ...          ...             ...
# 786171   1/09/2022       Azules      16/09/2022
# 786172   1/09/2022       Azules      23/09/2022
# 786173   1/09/2022       Azules       7/09/2022
# 786174   1/09/2022       Azules       7/09/2022
# 786175   1/09/2022       Azules       7/09/2022
#
# [11860594 rows x 45 columns]

# %%
df_DC['MesRad'] = pd.to_datetime(df_DC['MesRad'], errors='coerce', format = ('%d/%m/%Y'))
df_DC['FechaPrestacion'] = pd.to_datetime(df_DC['FechaPrestacion'], errors='coerce', format = ('%d/%m/%Y'))

# %%
df_DC['AnioMes_Acc'] = ((df_DC['FechaPrestacion'].dt.year * 100) + df_DC['FechaPrestacion'].dt.month).astype(float)
df_DC['AnioMes_Rad'] = ((df_DC['MesRad'].dt.year * 100) + df_DC['MesRad'].dt.month).astype(float)
df_DC['Anio_Acc'] = (df_DC['FechaPrestacion'].dt.year).astype(float)
df_DC['Anio_Rad'] = (df_DC['MesRad'].dt.year).astype(float)

# %%
df_DC['VrFac'] = df_DC['VrFacturado']/1000000
df_DC['GlosaAce'] = df_DC['GlosaAceptada']/1000000
df_DC['GlosaApp'] = df_DC['GlosaAplicada']/1000000
df_DC['CM'] = df_DC['CostoMedico']/1000000
df_DC['Ded'] = df_DC['Bonos']/1000000
df_DC['CMwoDed'] = df_DC['CostomenosBonos']/1000000

# %%
df_DC['CM'].sum()
# Out:
# 1048377.8068700014

# %%
df_DC['PE'] = df_DC['IPS'].str.contains('CRI-|BLUECARE|CLINICA AZUL', na = False)
df_DC['BC'] = df_DC['IPS'].str.contains('CRI-|BLUECARE', na = False)

# %%
df_DC['Anio_Acc'] = df_DC['Anio_Acc'].fillna(0)
df_DC['AnioMes_Acc'] = df_DC['AnioMes_Acc'].fillna(0)
df_DC['AnioMes_Rad'] = df_DC['AnioMes_Rad'].fillna(0)
df_DC['CarnetUsuario'] = df_DC['CarnetUsuario'].fillna(0)
df_DC['Sexo'] = df_DC['Sexo'].fillna(0)
df_DC['Edad'] = df_DC['Edad'].fillna(0)
df_DC['RangoEtareo'] = df_DC['RangoEtareo'].fillna(0)
df_DC['PlanCosto'] = df_DC['PlanCosto'].fillna(0)
df_DC['NombrePlancosto'] = df_DC['NombrePlancosto'].fillna(0)
df_DC['NAP'] = df_DC['NAP'].fillna(0)
df_DC['TipoServicioAgrupado'] = df_DC['TipoServicioAgrupado'].fillna(0)
df_DC['TipoServicio'] = df_DC['TipoServicio'].fillna(0)
df_DC['TipoContrato'] = df_DC['TipoContrato'].fillna(0)
df_DC['codmatriz'] = df_DC['codmatriz'].fillna(0)
df_DC['Codips'] = df_DC['Codips'].fillna(0)
df_DC['IPS'] = df_DC['IPS'].fillna(0)
df_DC['NAP'] = df_DC['NAP'].fillna(0)
df_DC['Area'] = df_DC['Area'].fillna(0)
df_DC['Ambito'] = df_DC['Ambito'].fillna(0)
df_DC['SucursalRad'] = df_DC['SucursalRad'].fillna(0)
df_DC['SucursalContrato'] = df_DC['SucursalContrato'].fillna(0)
df_DC['PE'] = df_DC['PE'].fillna(0)
df_DC['TipoCosto'] = df_DC['TipoCosto'].fillna(0)
df_DC['PatologiaAC'] = df_DC['PatologiaAC'].fillna(0)

# %%
df_DC['CM'].sum()
# Out:
# 1048377.8068700014

# %%
df_DC.loc[df_DC['Codips'] == 25173, 'Codips'] = 73004

# %%
df_DC['IPS'] = df_DC['IPS'].str.strip()

# %%
df_DC['IPS'] = df_DC['IPS'].fillna('0')

# %%
#df_DC_IPS = pd.DataFrame(df_DC.groupby(['Codips', 'IPS', 'Anio_Rad']).agg({'CM':sum}).astype(float).reset_index())

# %%
#df_DC_IPS = df_DC_IPS.reset_index()
#df_DC_IPS.to_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_202209\Results\IPS_Fully.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
#Level_IPS = pd.read_csv('D:\RODRIY21\A_DB\DB_CostoMedico\A_DB_CM_Test\IPS_Codes.csv',index_col = False, encoding='latin-1', sep = ';')

# %%
#df_LevelIPS = pd.DataFrame(Level_IPS)

# %%
#df_DC_1 = pd.merge(left = df_DC, right = df_LevelIPS, how = 'left', left_on = (['Codips', 'IPS']), right_on = (['Codips_Origen', 'IPS_Origen']))

# %%
#df_DC_1['New_IPS'] = df_DC_1['New_IPS'].fillna(0)
#df_DC_1['Level_IPS'] = df_DC_1['Level_IPS'].fillna(0)

# %%
#df_DC_1['CM'].sum()

# %%
df_DC_TSA = pd.DataFrame(df_DC.groupby(['Ambito', 'TipoServicioAgrupado']).agg({'CM':sum}).astype(float).reset_index())
df_DC_TSA
# Out:
#           Ambito         TipoServicioAgrupado             CM
# 0              0                            0       0.000000
# 1    Ambulatorio              CX Ambulatorias  136170.533781
# 2    Ambulatorio            Consultas Medicas  117559.952384
# 3    Ambulatorio           Honorarios Medicos   38021.850914
# 4    Ambulatorio        Imagenes Diagnosticas   92407.233687
# 5    Ambulatorio                  Laboratorio   78921.671037
# 6    Ambulatorio              MC Dispensacion   31592.216305
# 7    Ambulatorio           MC-SM Ambulatorios   27651.340035
# 8    Ambulatorio  Procedimientos Diagnosticos   38834.922779
# 9    Ambulatorio  Procedimientos Terapeuticos   71156.610752
# 10   Ambulatorio      Servicios Domiciliarios   23743.196141
# 11   Ambulatorio                    Urgencias   58193.438965
# 12         Glosa             Conciliacion IPS    6347.795263
# 13         Glosa               Objecion Glosa    6306.832730
# 14  Hospitalario             CX Hospitalarias  201850.082819
# 15  Hospitalario       Hospitalizacion Medica  111798.863398
# 16           PGP                          PGP    6630.779438
# 17    Reembolsos                    Reembolso    1190.486442

# %%
df_DC_TSA = df_DC_TSA.reset_index()
df_DC_TSA.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\TSA_Amb_Fully.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
Tipo_Servicio = pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Work\TSA_Fully.csv',index_col = False, encoding='latin-1', sep = ';')
df_TServ_F = pd.DataFrame(Tipo_Servicio)

# %%
df_DC_1 = pd.merge(left = df_DC, right = df_TServ_F, how = 'left', left_on = (['TipoServicioAgrupado']), right_on = (['TSA']))

# %%
df_DC_1['TSA'] = df_DC_1['TSA'].fillna(0)
df_DC_1['T_ServFinal'] = df_DC_1['T_ServFinal'].fillna(0)

# %%
df_DC_2 = pd.DataFrame(df_DC_1.groupby(['AnioMes_Acc', 'CarnetUsuario', 'Edad', 'Sexo', 'NAP', 'TSA', 'NombrePlancosto', 'SucursalContrato',
                                        'TipoContrato', ]).agg({'CM':sum, 'Ded':sum}).astype(float).reset_index())
df_DC_2
# Out:
#          AnioMes_Acc CarnetUsuario  Edad Sexo             NAP  \
# 0                0.0             0   0.0    0               0
# 1           199401.0      10049404  29.0    M  73008-20468479
# 2           199401.0      30024802  45.0    F  12327-18449959
# 3           199401.0      30318601  41.0    F  13290-19879979
# 4           199401.0      30792601  21.0    F  68431-16529558
# ...              ...           ...   ...  ...             ...
# 6542609     202209.0       9952502  83.0    M  12999-30259362
# 6542610     202209.0       9954501  59.0    M  11356-30072976
# 6542611     202209.0       9954501  59.0    M  11356-30072981
# 6542612     202209.0       9955401  72.0    F  11356-30141050
# 6542613     202209.0       9983402  75.0    F  12999-30120775
#
#                                  TSA      NombrePlancosto SucursalContrato  \
# 0                                  0                    0                0
# 1                  Consultas Medicas    Pergamino Excelso           IBAGUE
# 2                 MC-SM Ambulatorios        Simultaneidad           BOGOTA
# 3        Procedimientos Diagnosticos         Cafe Gourmet        CARTAGENA
# 4                 Honorarios Medicos  Cereza Excelso Plus      BUCARAMANGA
# ...                              ...                  ...              ...
# 6542609            Consultas Medicas         Cafe Gourmet            NEIVA
# 6542610        Imagenes Diagnosticas         Cafe Excelso            NEIVA
# 6542611        Imagenes Diagnosticas         Cafe Excelso            NEIVA
# 6542612        Imagenes Diagnosticas         Cafe Excelso            NEIVA
# 6542613            Consultas Medicas         Cafe Gourmet          ARMENIA
#
#         TipoContrato        CM      Ded
# 0                  0  0.000000  0.00000
# 1                  F  0.065000  0.02610
# 2                  F  0.280000  0.01130
# 3                  A  0.244800  0.02920
# 4                  A  0.273000  0.00000
# ...              ...       ...      ...
# 6542609            F  0.063348  0.02445
# 6542610            A  0.079057  0.00000
# 6542611            A  0.118836  0.00000
# 6542612            F  0.082034  0.00000
# 6542613            A  0.063348  0.02445
#
# [6542614 rows x 11 columns]

# %%
df_DC_2['CM'].sum()
# Out:
# 1048377.8068699988

# %%
df_DC_2.loc[df_DC_2['CM'] <= 0, 'Conteo'] = 0 
df_DC_2.loc[df_DC_2['CM'] > 0, 'Conteo'] = 1

# %%
df_CM = pd.DataFrame(df_DC_2.loc[df_DC_2['AnioMes_Acc'] > 201612])
df_CM
# Out:
#          AnioMes_Acc CarnetUsuario  Edad Sexo             NAP  \
# 85659       201701.0       7776401  69.0    M  77152-17957155
# 85660       201701.0       9345401  74.0    M               0
# 85661       201701.0       9352401  58.0    F  68013-17838509
# 85662       201701.0       9431802  55.0    F               0
# 85663       201701.0      10250801  74.0    M  54326-17916466
# ...              ...           ...   ...  ...             ...
# 6542609     202209.0       9952502  83.0    M  12999-30259362
# 6542610     202209.0       9954501  59.0    M  11356-30072976
# 6542611     202209.0       9954501  59.0    M  11356-30072981
# 6542612     202209.0       9955401  72.0    F  11356-30141050
# 6542613     202209.0       9983402  75.0    F  12999-30120775
#
#                            TSA    NombrePlancosto SucursalContrato  \
# 85659        Consultas Medicas  Pergamino Excelso           BOGOTA
# 85660         Conciliacion IPS       Cafe Gourmet      BUCARAMANGA
# 85661         Conciliacion IPS       Cafe Excelso      BUCARAMANGA
# 85662         Conciliacion IPS       Cafe Excelso      BUCARAMANGA
# 85663        Consultas Medicas       Cafe Gourmet           CUCUTA
# ...                        ...                ...              ...
# 6542609      Consultas Medicas       Cafe Gourmet            NEIVA
# 6542610  Imagenes Diagnosticas       Cafe Excelso            NEIVA
# 6542611  Imagenes Diagnosticas       Cafe Excelso            NEIVA
# 6542612  Imagenes Diagnosticas       Cafe Excelso            NEIVA
# 6542613      Consultas Medicas       Cafe Gourmet          ARMENIA
#
#         TipoContrato        CM      Ded  Conteo
# 85659              A  0.029000  0.02330     1.0
# 85660              F  0.000000  0.00000     0.0
# 85661              F  0.000000  0.00000     0.0
# 85662              F  0.000000  0.00000     0.0
# 85663              A  0.057800  0.02700     1.0
# ...              ...       ...      ...     ...
# 6542609            F  0.063348  0.02445     1.0
# 6542610            A  0.079057  0.00000     1.0
# 6542611            A  0.118836  0.00000     1.0
# 6542612            F  0.082034  0.00000     1.0
# 6542613            A  0.063348  0.02445     1.0
#
# [6456955 rows x 12 columns]

# %%
df_1 = pd.DataFrame(df_CM.loc[df_DC_2['Conteo'] == 0])
df_1
# Out:
#          AnioMes_Acc CarnetUsuario  Edad Sexo             NAP  \
# 85660       201701.0       9345401  74.0    M               0
# 85661       201701.0       9352401  58.0    F  68013-17838509
# 85662       201701.0       9431802  55.0    F               0
# 85669       201701.0      30034901  64.0    M               0
# 85670       201701.0      30357901  67.0    M  66037-17851960
# ...              ...           ...   ...  ...             ...
# 6542318     202209.0       9159401  75.0    F  76029-30156975
# 6542411     202209.0       9493001  83.0    M  66662-30320340
# 6542449     202209.0       9567502  52.0    M  11026-30117559
# 6542466     202209.0       9622702  65.0    F               0
# 6542498     202209.0       9644602  73.0    F  17531-30150975
#
#                                  TSA    NombrePlancosto SucursalContrato  \
# 85660               Conciliacion IPS       Cafe Gourmet      BUCARAMANGA
# 85661               Conciliacion IPS       Cafe Excelso      BUCARAMANGA
# 85662               Conciliacion IPS       Cafe Excelso      BUCARAMANGA
# 85669               Conciliacion IPS       Cafe Excelso      BUCARAMANGA
# 85670               Conciliacion IPS     Cereza Excelso          PEREIRA
# ...                              ...                ...              ...
# 6542318                  Laboratorio       Cafe Excelso             CALI
# 6542411              CX Ambulatorias       Cafe Excelso          PEREIRA
# 6542449  Procedimientos Terapeuticos       Cafe Excelso          PEREIRA
# 6542466                    Reembolso  Pergamino Excelso          PEREIRA
# 6542498              CX Ambulatorias  Pergamino Excelso        MANIZALES
#
#         TipoContrato   CM  Ded  Conteo
# 85660              F  0.0  0.0     0.0
# 85661              F  0.0  0.0     0.0
# 85662              F  0.0  0.0     0.0
# 85669              F  0.0  0.0     0.0
# 85670              A  0.0  0.0     0.0
# ...              ...  ...  ...     ...
# 6542318            F  0.0  0.0     0.0
# 6542411            F  0.0  0.0     0.0
# 6542449            F  0.0  0.0     0.0
# 6542466            A  0.0  0.0     0.0
# 6542498            A  0.0  0.0     0.0
#
# [121913 rows x 12 columns]

# %%
df_1['Conteo'].sum()
# Out:
# 0.0

# %%
df_1 = df_1.reset_index()
df_1.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\CM_Neg_202209.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
df_CM['Conteo'].sum()
# Out:
# 6335042.0

# %%
df_CM.drop(df_CM.loc[df_CM['Conteo'] == 0].index, inplace=True)
df_CM['Conteo'].count()
# Out:
# AnioMes_Acc         6335042
# CarnetUsuario       6335042
# Edad                6335042
# Sexo                6335042
# NAP                 6335042
# TSA                 6335042
# NombrePlancosto     6335042
# SucursalContrato    6335042
# TipoContrato        6335042
# CM                  6335042
# Ded                 6335042
# Conteo              6335042
# dtype: int64

# %%
df_CM = df_CM.reset_index()
df_CM.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\CM_2017-202209.txt', sep = ';', encoding = 'utf-8', index = False)
