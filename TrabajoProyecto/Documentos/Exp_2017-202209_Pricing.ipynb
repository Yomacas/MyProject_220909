# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import datetime as dt
import re

# %% [markdown]
# # Archivo central para estimación de freq, Actuaría

# %%
ExpAct_17_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2017_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_17_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2017_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_18_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2018_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_18_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2018_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_19_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2019_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_19_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2019_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_20_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2020_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_20_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2020_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_21_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2021_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_21_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2021_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
ExpAct_22_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Act_DB\IngUsuExp_2022_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)

# %%
a1, a2, a3, a4, a5, a6 = ExpAct_17_1['Mes'].count(), ExpAct_17_2['Mes'].count(), ExpAct_18_1['Mes'].count(), ExpAct_18_2['Mes'].count(), ExpAct_19_1['Mes'].count(), ExpAct_19_2['Mes'].count(),
a1, a2, a3, a4, a5, a6
# Out:
# (552107, 560980, 564525, 566915, 1031832, 93541)

# %%
a7, a8, a9, a10, a11 = ExpAct_20_1['Mes'].count(), ExpAct_20_2['Mes'].count(), ExpAct_21_1['Mes'].count(), ExpAct_21_2['Mes'].count(), ExpAct_22_1['Mes'].count()
a7, a8, a9, a10, a11
# Out:
# (1029737, 93542, 1031384, 94425, 844738)

# %%
ExpAct_22_1.dtypes
# Out:
# Anio                    int64
# Mes                     int64
# AnioIng                 int64
# MesIng                  int64
# numerocontrato          int64
# CarnetUsuario           int64
# Parentesco             object
# Edad                    int64
# Sexo                   object
# GrupoEtareo            object
# TipoContrato           object
# nombreplan             object
# CodMatriz               int64
# ValorPrima              int64
# ValorPos                int64
# ValorNotas              int64
# ValorAdicional          int64
# ValorDtoPtoPago         int64
# VrIngConDtoPtoPago      int64
# Tipo                   object
# ciudad                 object
# Tarifa                 object
# VrIngSinDtoPtoPago      int64
# Participacion         float64
# dtype: object

# %%
ExpAct_Total = pd.concat([ExpAct_17_1, ExpAct_17_2, ExpAct_18_1, ExpAct_18_2, ExpAct_19_1, ExpAct_19_2, ExpAct_20_1, ExpAct_20_2, ExpAct_21_1, ExpAct_21_2, ExpAct_22_1],
                         axis = 0, ignore_index = False, keys = None, sort = False, copy = True)
ExpAct_Total['MesIng'].count()
# Out:
# 6463726

# %%
ExpAct_Total
# Out:
#         Anio  Mes  AnioIng  MesIng  numerocontrato  CarnetUsuario Parentesco  \
# 0       2017    1     2017       1             307          30701         CT
# 1       2017    1     2017       1             307          30702         CO
# 2       2017    1     2017       1             307          30703         HI
# 3       2017    1     2017       1             307          30706         OH
# 4       2017    1     2017       1             329          32901         CT
# ...      ...  ...      ...     ...             ...            ...        ...
# 844733  2022    9     2022       9          349786       34978604         HI
# 844734  2022    9     2022       9           34979        3497901         CO
# 844735  2022    9     2022       9           34979        3497902         HI
# 844736  2022    9     2022       9           34979        3497903         CT
# 844737  2022    9     2022       9          349792       34979201         HI
#
#         Edad Sexo      GrupoEtareo  ... ValorPos ValorNotas  ValorAdicional  \
# 0         62    M  i. 60 - 64 Años  ...        0          0               0
# 1         57    F  h. 55 - 59 Años  ...        0          0               0
# 2         26    F  e. 19 - 44 Años  ...        0          0               0
# 3         22    F  e. 19 - 44 Años  ...        0          0               0
# 4         51    F  g. 50 - 54 Años  ...   -12000          0               0
# ...      ...  ...              ...  ...      ...        ...             ...
# 844733     6    F   c. 5 - 14 Años  ...        0          0               0
# 844734    56    F  h. 55 - 59 Años  ...        0          0               0
# 844735    22    M  e. 19 - 44 Años  ...        0          0               0
# 844736    55    M  h. 55 - 59 Años  ...        0          0               0
# 844737    39    F  e. 19 - 44 Años  ...    -3999       7233               0
#
#         ValorDtoPtoPago  VrIngConDtoPtoPago  Tipo    ciudad  \
# 0                     0              105139   Mes    BOGOTA
# 1                     0              105139   Mes    BOGOTA
# 2                     0              105139   Mes    BOGOTA
# 3                     0               87321   Mes    BOGOTA
# 4                     0               74100   Mes    BOGOTA
# ...                 ...                 ...   ...       ...
# 844733                0              140928   Mes    IBAGUE
# 844734                0              138798   Mes  MEDELLIN
# 844735                0              138798   Mes  MEDELLIN
# 844736                0              138798   Mes  MEDELLIN
# 844737                0              107699   Mes    BOGOTA
#
#                             Tarifa  VrIngSinDtoPtoPago Participacion
# 0                 (3)Tres usuarios              105139             0
# 1                 (3)Tres usuarios              105139             0
# 2                 (3)Tres usuarios              105139             0
# 3       (4)Otro menor o igual a 30               87321             0
# 4                  (2)Dos usuarios               74100             0
# ...                            ...                 ...           ...
# 844733           (3)DE 5 A 14 AÑOS              140928       0.23267
# 844734            (3)Tres usuarios              138798       0.33333
# 844735            (3)Tres usuarios              138798       0.33333
# 844736            (3)Tres usuarios              138798       0.33333
# 844737            (3)Tres usuarios              107699       0.33333
#
# [6463726 rows x 24 columns]

# %%
df_ExpAct = pd.DataFrame(ExpAct_Total)

# %%
del [[ExpAct_17_1, ExpAct_17_2, ExpAct_18_1, ExpAct_18_2, ExpAct_19_1, ExpAct_19_2, ExpAct_20_1, ExpAct_20_2, ExpAct_21_1, ExpAct_21_2, ExpAct_22_1, ExpAct_Total]]

# %%
df_ExpAct.describe()
# Out:
#                Anio           Mes       AnioIng        MesIng  numerocontrato  \
# count  6.463726e+06  6.463726e+06  6.463726e+06  6.463726e+06    6.463726e+06
# mean   2.019394e+03  6.311164e+00  2.019395e+03  6.310651e+00    3.201067e+05
# std    1.659747e+00  3.390652e+00  1.659735e+00  3.390298e+00    1.198021e+05
# min    2.012000e+03  1.000000e+00  2.017000e+03  1.000000e+00    3.070000e+02
# 25%    2.018000e+03  3.000000e+00  2.018000e+03  3.000000e+00    3.169062e+05
# 50%    2.019000e+03  6.000000e+00  2.019000e+03  6.000000e+00    3.616160e+05
# 75%    2.021000e+03  9.000000e+00  2.021000e+03  9.000000e+00    3.957450e+05
# max    2.022000e+03  1.200000e+01  2.022000e+03  1.200000e+01    4.513590e+05
#
#        CarnetUsuario          Edad     CodMatriz    ValorPrima      ValorPos  \
# count   6.463726e+06  6.463726e+06  5.363188e+06  6.463726e+06  6.463726e+06
# mean    3.188778e+07  3.699240e+01  5.845480e+02  2.306929e+05 -1.057173e+03
# std     1.210444e+07  2.169833e+01  3.544594e+02  2.111099e+05  2.902547e+03
# min     0.000000e+00  0.000000e+00  0.000000e+00 -2.438150e+07 -1.592000e+05
# 25%     3.162950e+07  2.000000e+01  3.390000e+02  1.361630e+05  0.000000e+00
# 50%     3.612040e+07  3.700000e+01  6.140000e+02  1.764030e+05  0.000000e+00
# 75%     3.955290e+07  5.400000e+01  6.550000e+02  2.467000e+05  0.000000e+00
# max     4.513590e+07  1.070000e+02  1.522000e+03  1.357200e+07  6.000000e+05
#
#          ValorNotas  ValorAdicional  ValorDtoPtoPago  VrIngConDtoPtoPago  \
# count  6.463726e+06    6.463726e+06     6.463726e+06        6.463726e+06
# mean  -7.132791e+02   -2.160561e+01    -7.362224e+02        2.272543e+05
# std    2.947953e+04    8.347733e+04     1.168024e+04        2.082779e+05
# min   -1.091947e+07   -3.886987e+06    -1.043845e+06       -2.415750e+07
# 25%    0.000000e+00    0.000000e+00     0.000000e+00        1.319620e+05
# 50%    0.000000e+00    0.000000e+00     0.000000e+00        1.744840e+05
# 75%    0.000000e+00    0.000000e+00     0.000000e+00        2.446790e+05
# max    4.305024e+06    1.985760e+07     1.761968e+06        8.688600e+06
#
#        VrIngSinDtoPtoPago
# count        6.463726e+06
# mean         2.279906e+05
# std          2.082248e+05
# min         -2.415750e+07
# 25%          1.326770e+05
# 50%          1.747000e+05
# 75%          2.458120e+05
# max          8.688600e+06

# %%
df_ExpAct['Periodo'] = (df_ExpAct['AnioIng'] * 100 + df_ExpAct['MesIng']).astype(float)

# %%
df_ExpAct['Premium'] = (df_ExpAct['ValorPrima']/1000000).astype(float)
df_ExpAct['VrPOS'] = (df_ExpAct['ValorPos']/1000000).astype(float)
df_ExpAct['VrNC'] = (df_ExpAct['ValorNotas']/1000000).astype(float)
df_ExpAct['VrAdd'] = (df_ExpAct['ValorAdicional']/1000000).astype(float)
df_ExpAct['DtoPtoPag'] = (df_ExpAct['ValorDtoPtoPago']/1000000).astype(float)
df_ExpAct['P_NetPtoPag'] = (df_ExpAct['VrIngConDtoPtoPago']/1000000).astype(float)
df_ExpAct['P_GrossPtoPag'] = (df_ExpAct['VrIngSinDtoPtoPago']/1000000).astype(float)

# %%
df_ExpAct['Parentesco'] = df_ExpAct['Parentesco'].str.strip()
df_ExpAct['Sexo'] = df_ExpAct['Sexo'].str.strip()
df_ExpAct['TipoContrato'] = df_ExpAct['TipoContrato'].str.strip()
df_ExpAct['nombreplan'] = df_ExpAct['nombreplan'].str.strip()
df_ExpAct['Tipo'] = df_ExpAct['Tipo'].str.strip()
df_ExpAct['ciudad'] = df_ExpAct['ciudad'].str.strip()

# %%
df_ExpAct['Parentesco'] = df_ExpAct['Parentesco'].fillna('0')
df_ExpAct['Edad'] = df_ExpAct['Edad'].fillna(9999)
df_ExpAct['Sexo'] = df_ExpAct['Sexo'].fillna('0')
df_ExpAct['TipoContrato'] = df_ExpAct['TipoContrato'].fillna('0')
df_ExpAct['nombreplan'] = df_ExpAct['nombreplan'].fillna('0')
df_ExpAct['CodMatriz'] = df_ExpAct['CodMatriz'].fillna(9999)
df_ExpAct['Tipo'] = df_ExpAct['Tipo'].fillna('0')
df_ExpAct['ciudad'] = df_ExpAct['ciudad'].fillna('0')

# %%
df_ExpAct['P_NetPtoPag'].sum()
# Out:
# 1468909.763551001

# %%
FecAnalysis = pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Work\FecPerAnalysis.csv', index_col = False, encoding='latin-1', sep = ';')

# %%
df_FecAnalysis = pd.DataFrame(FecAnalysis)

# %%
df_ExpAct = pd.merge(left = df_ExpAct, right = df_FecAnalysis, how = 'left', left_on = (['Periodo']), right_on = (['AñoMes_V']))

# %%
df_ExpAct['FecIni_Per'] = pd.to_datetime(df_ExpAct['FecIni_Per'], errors='coerce', format = ('%d/%m/%Y'))
df_ExpAct['FecFin_Per'] = pd.to_datetime(df_ExpAct['FecFin_Per'], errors='coerce', format = ('%d/%m/%Y'))

# %%
df_ExpAct_Agg = pd.DataFrame(df_ExpAct.groupby(['Periodo', 'FecIni_Per', 'FecFin_Per', 'numerocontrato', 'CarnetUsuario', 'Parentesco',
                                                'Edad', 'Sexo', 'TipoContrato', 'nombreplan', 'CodMatriz',
                                                'ciudad']).agg({'Premium':sum, 'P_NetPtoPag':sum, 'P_GrossPtoPag': sum}).astype(float).reset_index())
df_ExpAct_Agg
# Out:
#           Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 0        201701.0 2017-01-01 2017-01-31             307          30701
# 1        201701.0 2017-01-01 2017-01-31             307          30702
# 2        201701.0 2017-01-01 2017-01-31             307          30703
# 3        201701.0 2017-01-01 2017-01-31             307          30706
# 4        201701.0 2017-01-01 2017-01-31             329          32901
# ...           ...        ...        ...             ...            ...
# 6463721  202209.0 2022-09-01 2022-09-30          451359       45135901
# 6463722  202209.0 2022-09-01 2022-09-30          451359       45135902
# 6463723  202209.0 2022-09-01 2022-09-30          451359       45135903
# 6463724  202209.0 2022-09-01 2022-09-30          451359       45135904
# 6463725  202209.0 2022-09-01 2022-09-30          451359       45135905
#
#         Parentesco  Edad Sexo TipoContrato    nombreplan  CodMatriz  ciudad  \
# 0               CT    62    M            F  Cafe Excelso     9999.0  BOGOTA
# 1               CO    57    F            F  Cafe Excelso     9999.0  BOGOTA
# 2               HI    26    F            F  Cafe Excelso     9999.0  BOGOTA
# 3               OH    22    F            F  Cafe Excelso     9999.0  BOGOTA
# 4               CT    51    F            C  Cafe Excelso        3.0  BOGOTA
# ...            ...   ...  ...          ...           ...        ...     ...
# 6463721         OT    44    M            A  Celeste Plus      714.0  BOGOTA
# 6463722         OT    32    F            A  Celeste Plus      714.0  BOGOTA
# 6463723         OT    10    F            A  Celeste Plus      714.0  BOGOTA
# 6463724         OT    19    M            A  Celeste Plus      714.0  BOGOTA
# 6463725         OT     1    M            A  Celeste Plus      714.0  BOGOTA
#
#           Premium  P_NetPtoPag  P_GrossPtoPag
# 0        0.105139     0.105139       0.105139
# 1        0.105139     0.105139       0.105139
# 2        0.105139     0.105139       0.105139
# 3        0.087321     0.087321       0.087321
# 4        0.086100     0.074100       0.074100
# ...           ...          ...            ...
# 6463721  0.186924     0.186924       0.186924
# 6463722  0.200315     0.200315       0.200315
# 6463723  0.157268     0.157268       0.157268
# 6463724  0.186924     0.186924       0.186924
# 6463725  0.188958     0.188958       0.188958
#
# [6463726 rows x 15 columns]

# %%
df_ExpAct_Agg.dtypes
# Out:
# Periodo                  float64
# FecIni_Per        datetime64[ns]
# FecFin_Per        datetime64[ns]
# numerocontrato             int64
# CarnetUsuario              int64
# Parentesco                object
# Edad                       int64
# Sexo                      object
# TipoContrato              object
# nombreplan                object
# CodMatriz                float64
# ciudad                    object
# Premium                  float64
# P_NetPtoPag              float64
# P_GrossPtoPag            float64
# dtype: object

# %%
del [[df_ExpAct]]

# %%
df_ExpAct_Agg.loc[df_ExpAct_Agg['Premium'] <= 0, 'Conteo'] = 0
df_ExpAct_Agg.loc[df_ExpAct_Agg['Premium'] > 0, 'Conteo'] = 1

# %%
# Estados apriori 
conditions = [
    (df_ExpAct_Agg['Premium'] < 0),
    (df_ExpAct_Agg['Premium'] == 0),
    (df_ExpAct_Agg['Premium'] > 0)
]
values = ['Cancel', 'Move_w/oP', 'Inforce']
df_ExpAct_Agg['TypePaid'] = np.select(conditions, values)
df_ExpAct_Agg.head()
# Out:
#     Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario Parentesco  \
# 0  201701.0 2017-01-01 2017-01-31             307          30701         CT
# 1  201701.0 2017-01-01 2017-01-31             307          30702         CO
# 2  201701.0 2017-01-01 2017-01-31             307          30703         HI
# 3  201701.0 2017-01-01 2017-01-31             307          30706         OH
# 4  201701.0 2017-01-01 2017-01-31             329          32901         CT
#
#    Edad Sexo TipoContrato    nombreplan  CodMatriz  ciudad   Premium  \
# 0    62    M            F  Cafe Excelso     9999.0  BOGOTA  0.105139
# 1    57    F            F  Cafe Excelso     9999.0  BOGOTA  0.105139
# 2    26    F            F  Cafe Excelso     9999.0  BOGOTA  0.105139
# 3    22    F            F  Cafe Excelso     9999.0  BOGOTA  0.087321
# 4    51    F            C  Cafe Excelso        3.0  BOGOTA  0.086100
#
#    P_NetPtoPag  P_GrossPtoPag  Conteo TypePaid
# 0     0.105139       0.105139     1.0  Inforce
# 1     0.105139       0.105139     1.0  Inforce
# 2     0.105139       0.105139     1.0  Inforce
# 3     0.087321       0.087321     1.0  Inforce
# 4     0.074100       0.074100     1.0  Inforce

# %%
df_ExpAct_Agg['Periodo_1'] = df_ExpAct_Agg['Periodo'].apply(lambda x: (x - 89) if (x % 100) == 1 else (x - 1))
df_ExpAct_Agg.head()
# Out:
#     Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario Parentesco  \
# 0  201701.0 2017-01-01 2017-01-31             307          30701         CT
# 1  201701.0 2017-01-01 2017-01-31             307          30702         CO
# 2  201701.0 2017-01-01 2017-01-31             307          30703         HI
# 3  201701.0 2017-01-01 2017-01-31             307          30706         OH
# 4  201701.0 2017-01-01 2017-01-31             329          32901         CT
#
#    Edad Sexo TipoContrato    nombreplan  CodMatriz  ciudad   Premium  \
# 0    62    M            F  Cafe Excelso     9999.0  BOGOTA  0.105139
# 1    57    F            F  Cafe Excelso     9999.0  BOGOTA  0.105139
# 2    26    F            F  Cafe Excelso     9999.0  BOGOTA  0.105139
# 3    22    F            F  Cafe Excelso     9999.0  BOGOTA  0.087321
# 4    51    F            C  Cafe Excelso        3.0  BOGOTA  0.086100
#
#    P_NetPtoPag  P_GrossPtoPag  Conteo TypePaid  Periodo_1
# 0     0.105139       0.105139     1.0  Inforce   201612.0
# 1     0.105139       0.105139     1.0  Inforce   201612.0
# 2     0.105139       0.105139     1.0  Inforce   201612.0
# 3     0.087321       0.087321     1.0  Inforce   201612.0
# 4     0.074100       0.074100     1.0  Inforce   201612.0

# %% [markdown]
# # Archivo que contiene las fechas de vigencia, área Técnica

# %%
Exp_17_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2017_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_17_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2017_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_18_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2018_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_18_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2018_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_19_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2019_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_19_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2019_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_20_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2020_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_20_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2020_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_21_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2021_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_21_2= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2021_2.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)
Exp_22_1= pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\ATec_DB\Usuarios_2022_1.csv', index_col = False, encoding='latin-1', sep = ';', low_memory = False)

# %%
a12, a13, a14, a15, a16, a17 = Exp_17_1['MES'].count(), Exp_17_2['MES'].count(), Exp_18_1['MES'].count(), Exp_18_2['MES'].count(), Exp_19_1['MES'].count(), Exp_19_2['MES'].count()
a12, a13, a14, a15, a16, a17
# Out:
# (1006973, 92905, 1024068, 93402, 1018799, 92441)

# %%
a18, a19, a20, a21, a22 = Exp_20_1['MES'].count(), Exp_20_2['MES'].count(), Exp_21_1['MES'].count(), Exp_21_2['MES'].count(), Exp_22_1['MES'].count()
a18, a19, a20, a21, a22
# Out:
# (1014790, 92116, 919567, 184856, 827380)

# %%
Exp_22_1.dtypes
# Out:
# AÑO                          int64
# MES                         object
# CIUDAD SERVICIO              int64
# Ciudad                      object
# COD CONCEPTO CONTRATO        int64
# COD ESTADO BENEFICIARIO     object
# CODPLAN                     object
# Nombre Plan                 object
# NUMERO CONTRATO              int64
# TIPO CONTRATO               object
# CODMATRIZ                  float64
# NUM ALIANZA                float64
# NUMERO BENEFICIA             int64
# Carnet                       int64
# TIPO ID                     object
# IDENTIFICACION              object
# NOMBRE 1                    object
# NOMBRE 2                    object
# APELLIDO 1                  object
# APELLIDO 2                  object
# COD PARENT                  object
# FECHA NACIMIENTO            object
# EDAD                         int64
# SEXO                        object
# COD EPS                     object
# NOMBRE EPS                  object
# Fecha afiliación            object
# FECHA INI VIGENCIA          object
# FECHA FIN VIGENCIA          object
# dtype: object

# %%
Exp_Total = pd.concat([Exp_17_1, Exp_17_2, Exp_18_1, Exp_18_2, Exp_19_1, Exp_19_2, Exp_20_1, Exp_20_2, Exp_21_1, Exp_21_2, Exp_22_1], axis = 0, ignore_index = False,
                      keys = None, sort = False, copy = True)
Exp_Total['Carnet'].count()
# Out:
# 6367298

# %%
Exp_Total
# Out:
#            AÑO         MES  CIUDAD SERVICIO  Ciudad  COD CONCEPTO CONTRATO  \
# 0       2017.0       Enero              1.0  BOGOTA                   70.0
# 1       2017.0       Enero              1.0  BOGOTA                   70.0
# 2       2017.0       Enero              1.0  BOGOTA                   81.0
# 3       2017.0       Enero              1.0  BOGOTA                   81.0
# 4       2017.0       Enero              1.0  BOGOTA                   81.0
# ...        ...         ...              ...     ...                    ...
# 827375  2022.0  Septiembre              1.0  BOGOTA                   80.0
# 827376  2022.0  Septiembre              1.0  BOGOTA                   80.0
# 827377  2022.0  Septiembre              1.0  BOGOTA                   80.0
# 827378  2022.0  Septiembre              1.0  BOGOTA                   80.0
# 827379  2022.0  Septiembre              1.0  BOGOTA                   80.0
#
#        COD ESTADO BENEFICIARIO CODPLAN          Nombre Plan  NUMERO CONTRATO  \
# 0                           AC       R         Café Excelso            329.0
# 1                           AC       R         Café Excelso            329.0
# 2                           AC       S  Cereza Excelso Plus            942.0
# 3                           AC       S  Cereza Excelso Plus            942.0
# 4                           AC       S  Cereza Excelso Plus            942.0
# ...                        ...     ...                  ...              ...
# 827375                      AC      SC         Celeste Plus         451359.0
# 827376                      AC      SC         Celeste Plus         451359.0
# 827377                      AC      SC         Celeste Plus         451359.0
# 827378                      AC      SC         Celeste Plus         451359.0
# 827379                      AC      SC         Celeste Plus         451359.0
#
#        TIPO CONTRATO  ...  APELLIDO 2  COD PARENT  FECHA NACIMIENTO  EDAD  \
# 0                  C  ...      SIERRA          CT        28/07/1965    51
# 1                  C  ...       ROCHA          HI         7/01/1999    18
# 2                  C  ...     CARMONA          CT        24/11/1961    55
# 3                  C  ...    MARTINEZ          CO         5/11/1962    54
# 4                  C  ...     BARAJAS          HI        14/11/1992    24
# ...              ...  ...         ...         ...               ...   ...
# 827375             A  ...    QUINTERO          OT         3/06/1978    44
# 827376             A  ...     JIMENEZ          OT         8/02/1990    32
# 827377             A  ...     CARDOZO          OT        10/07/2012    10
# 827378             A  ...       COTES          OT         2/07/2003    19
# 827379             A  ...     CARDOZO          OT        23/02/2021     1
#
#        SEXO COD EPS            NOMBRE EPS Fecha afiliación FECHA INI VIGENCIA  \
# 0         F  EPS003    CAFESALUD EPS S.A.        1/01/1992          1/01/2017
# 1         F  EPS003    CAFESALUD EPS S.A.        1/02/1999          1/01/2017
# 2         F  EPS003    CAFESALUD EPS S.A.        1/10/1997          1/01/2017
# 3         M  EPS003    CAFESALUD EPS S.A.        1/10/1997          1/01/2017
# 4         M  EPS003    CAFESALUD EPS S.A.        1/10/1997          1/01/2017
# ...     ...     ...                   ...              ...                ...
# 827375    M  EPS002  SALUD TOTAL EPS S.A.       30/09/2022         30/09/2022
# 827376    F  EPS002  SALUD TOTAL EPS S.A.       30/09/2022         30/09/2022
# 827377    F  EPS002  SALUD TOTAL EPS S.A.       30/09/2022         30/09/2022
# 827378    M  EPS002  SALUD TOTAL EPS S.A.       30/09/2022         30/09/2022
# 827379    M  EPS002  SALUD TOTAL EPS S.A.       30/09/2022         30/09/2022
#
#        FECHA FIN VIGENCIA
# 0              31/12/2017
# 1              31/12/2017
# 2              31/12/2017
# 3              31/12/2017
# 4              31/12/2017
# ...                   ...
# 827375         29/09/2023
# 827376         29/09/2023
# 827377         29/09/2023
# 827378         29/09/2023
# 827379         29/09/2023
#
# [6367299 rows x 29 columns]

# %%
df_Exp = pd.DataFrame(Exp_Total)

# %%
del [[Exp_17_1, Exp_17_2, Exp_18_1, Exp_18_2, Exp_19_1, Exp_19_2, Exp_20_1, Exp_20_2, Exp_21_1, Exp_21_2, Exp_22_1, Exp_Total]]

# %%
df_Exp['FECHA INI VIGENCIA'] = pd.to_datetime(df_Exp['FECHA INI VIGENCIA'], errors='coerce', format = ('%d/%m/%Y'))
df_Exp['FECHA FIN VIGENCIA'] = pd.to_datetime(df_Exp['FECHA FIN VIGENCIA'], errors='coerce', format = ('%d/%m/%Y'))
df_Exp['FECHA NACIMIENTO'] = pd.to_datetime(df_Exp['FECHA NACIMIENTO'], errors='coerce', format = ('%d/%m/%Y'))

# %%
df_Exp['COD PARENT'] = df_Exp['COD PARENT'].str.strip()
df_Exp['SEXO'] = df_Exp['SEXO'].str.strip()
df_Exp['Nombre Plan'] = df_Exp['Nombre Plan'].str.strip()
df_Exp['TIPO CONTRATO'] = df_Exp['TIPO CONTRATO'].str.strip()
df_Exp['Ciudad'] = df_Exp['Ciudad'].str.strip()

# %%
df_Exp['NUMERO CONTRATO'] = df_Exp['NUMERO CONTRATO'].fillna(98989898)
df_Exp['Carnet'] = df_Exp['Carnet'].fillna(98989898)
df_Exp['COD PARENT'] = df_Exp['COD PARENT'].fillna('0')
df_Exp['EDAD'] = df_Exp['EDAD'].fillna(9999)
df_Exp['SEXO'] = df_Exp['SEXO'].fillna('0')
df_Exp['TIPO CONTRATO'] = df_Exp['TIPO CONTRATO'].fillna('0')
df_Exp['Nombre Plan'] = df_Exp['Nombre Plan'].fillna('0')
df_Exp['CODMATRIZ'] = df_Exp['CODMATRIZ'].fillna(9999)
df_Exp['Ciudad'] = df_Exp['Ciudad'].fillna('0')
df_Exp['FECHA INI VIGENCIA'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)
df_Exp['FECHA FIN VIGENCIA'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)
df_Exp['FECHA NACIMIENTO'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)

# %%
Meses = pd.read_csv(r'D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Work\Meses.csv', index_col = False, encoding='latin-1', sep = ';')

# %%
df_Meses = pd.DataFrame(Meses)

# %%
df_Exp = pd.merge(left = df_Exp, right = df_Meses, how = 'left', left_on = (['MES']), right_on = (['Mes_L']))

# %%
df_Exp['AñoMes_Per'] = df_Exp['AÑO'] * 100 + df_Exp['Mes_N']

# %%
df_Exp['Conteo1'] = 1
df_Exp['Conteo1'].sum()
# Out:
# 6367299

# %%
df_Exp_Agg = pd.DataFrame(df_Exp.groupby(['AñoMes_Per', 'NUMERO CONTRATO', 'Carnet', 'FECHA INI VIGENCIA',
                                          'FECHA FIN VIGENCIA']).agg({'Conteo1':sum}).astype(float).reset_index())
#'FecIni_Per', 'FecFin_Per', 
df_Exp_Agg.head()
# Out:
#    AñoMes_Per  NUMERO CONTRATO   Carnet FECHA INI VIGENCIA FECHA FIN VIGENCIA  \
# 0    201701.0            307.0  30701.0         2017-01-01         2017-12-31
# 1    201701.0            307.0  30702.0         2017-01-01         2017-12-31
# 2    201701.0            307.0  30703.0         2017-01-01         2017-12-31
# 3    201701.0            307.0  30706.0         2017-01-01         2017-12-31
# 4    201701.0            329.0  32901.0         2017-01-01         2017-12-31
#
#    Conteo1
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0

# %%
df_Exp_Agg['Conteo1'].sum()
# Out:
# 6367297.0

# %% [markdown]
# # Obtener el máximo de AñoMes_Per y fechas de vigencia de los que no cruzan

# %%
#df_Exp['Key_1'] = df_Exp['NUMERO CONTRATO'].astype(str) + "_" + df_Exp['Carnet'].astype(str)

# %%
#df_Exp1 = pd.DataFrame(df_Exp.groupby(['Key_1', 'AñoMes_Per', 'FECHA INI VIGENCIA', 'FECHA FIN VIGENCIA']).agg({'Conteo':sum}).astype(float).reset_index())
#df_Exp1.head()

# %%
#cols = ['AñoMes_Per', 'FECHA INI VIGENCIA', 'FECHA FIN VIGENCIA']
#df_Exp1[cols] = df_Exp1[cols].fillna(np.inf)  # replace NaN with largest value
#df_Exp1 = df_Exp1.groupby('Key_1', as_index=False)[cols].max()  # Get Max Per Group
#df_Exp1[cols] = df_Exp1[cols].replace(np.inf, np.nan)  # Return to NaN
#df_Exp1

# %%
#df_Exp1 = df_Exp1.reset_index()
#df_Exp1.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\Exp_NAN_202209_NoCruxMax.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
#del [[df_Exp]]

# %% [markdown]
# # Cruce para obtener las fechas de vigencia en el archivo central

# %%
df_ExpPreliminary = pd.merge(left = df_ExpAct_Agg, right = df_Exp_Agg, how = 'left', left_on = (['Periodo', 'numerocontrato', 'CarnetUsuario']),
                             right_on = (['AñoMes_Per', 'NUMERO CONTRATO', 'Carnet']))

# %%
df_ExpPreliminary
# Out:
#           Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 0        201701.0 2017-01-01 2017-01-31             307          30701
# 1        201701.0 2017-01-01 2017-01-31             307          30702
# 2        201701.0 2017-01-01 2017-01-31             307          30703
# 3        201701.0 2017-01-01 2017-01-31             307          30706
# 4        201701.0 2017-01-01 2017-01-31             329          32901
# ...           ...        ...        ...             ...            ...
# 6463721  202209.0 2022-09-01 2022-09-30          451359       45135901
# 6463722  202209.0 2022-09-01 2022-09-30          451359       45135902
# 6463723  202209.0 2022-09-01 2022-09-30          451359       45135903
# 6463724  202209.0 2022-09-01 2022-09-30          451359       45135904
# 6463725  202209.0 2022-09-01 2022-09-30          451359       45135905
#
#         Parentesco  Edad Sexo TipoContrato    nombreplan  ...  P_GrossPtoPag  \
# 0               CT    62    M            F  Cafe Excelso  ...       0.105139
# 1               CO    57    F            F  Cafe Excelso  ...       0.105139
# 2               HI    26    F            F  Cafe Excelso  ...       0.105139
# 3               OH    22    F            F  Cafe Excelso  ...       0.087321
# 4               CT    51    F            C  Cafe Excelso  ...       0.074100
# ...            ...   ...  ...          ...           ...  ...            ...
# 6463721         OT    44    M            A  Celeste Plus  ...       0.186924
# 6463722         OT    32    F            A  Celeste Plus  ...       0.200315
# 6463723         OT    10    F            A  Celeste Plus  ...       0.157268
# 6463724         OT    19    M            A  Celeste Plus  ...       0.186924
# 6463725         OT     1    M            A  Celeste Plus  ...       0.188958
#
#         Conteo  TypePaid  Periodo_1  AñoMes_Per  NUMERO CONTRATO      Carnet  \
# 0          1.0   Inforce   201612.0    201701.0            307.0     30701.0
# 1          1.0   Inforce   201612.0    201701.0            307.0     30702.0
# 2          1.0   Inforce   201612.0    201701.0            307.0     30703.0
# 3          1.0   Inforce   201612.0    201701.0            307.0     30706.0
# 4          1.0   Inforce   201612.0    201701.0            329.0     32901.0
# ...        ...       ...        ...         ...              ...         ...
# 6463721    1.0   Inforce   202208.0    202209.0         451359.0  45135901.0
# 6463722    1.0   Inforce   202208.0    202209.0         451359.0  45135902.0
# 6463723    1.0   Inforce   202208.0    202209.0         451359.0  45135903.0
# 6463724    1.0   Inforce   202208.0    202209.0         451359.0  45135904.0
# 6463725    1.0   Inforce   202208.0    202209.0         451359.0  45135905.0
#
#          FECHA INI VIGENCIA  FECHA FIN VIGENCIA  Conteo1
# 0                2017-01-01          2017-12-31      1.0
# 1                2017-01-01          2017-12-31      1.0
# 2                2017-01-01          2017-12-31      1.0
# 3                2017-01-01          2017-12-31      1.0
# 4                2017-01-01          2017-12-31      1.0
# ...                     ...                 ...      ...
# 6463721          2022-09-30          2023-09-29      1.0
# 6463722          2022-09-30          2023-09-29      1.0
# 6463723          2022-09-30          2023-09-29      1.0
# 6463724          2022-09-30          2023-09-29      1.0
# 6463725          2022-09-30          2023-09-29      1.0
#
# [6463726 rows x 24 columns]

# %%
df_ExpPreliminary['Periodo'].count()
# Out:
# 6463726

# %%
df_ExpPreliminary['FECHA INI VIGENCIA'].isna().sum()
# Out:
# 96977

# %%
df_1 = pd.DataFrame(df_ExpPreliminary[df_ExpPreliminary['FECHA INI VIGENCIA'].isna()])
df_1
# Out:
#           Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 5613     201701.0 2017-01-01 2017-01-31           55559              0
# 7365     201701.0 2017-01-01 2017-01-31           65148        6514803
# 7367     201701.0 2017-01-01 2017-01-31           65148        6514805
# 8912     201701.0 2017-01-01 2017-01-31           70605        7060505
# 8930     201701.0 2017-01-01 2017-01-31           70653        7065301
# ...           ...        ...        ...             ...            ...
# 6463678  202209.0 2022-09-01 2022-09-30          451329       45132901
# 6463682  202209.0 2022-09-01 2022-09-30          451331       45133101
# 6463684  202209.0 2022-09-01 2022-09-30          451333       45133301
# 6463685  202209.0 2022-09-01 2022-09-30          451334       45133401
# 6463720  202209.0 2022-09-01 2022-09-30          451358       45135801
#
#         Parentesco  Edad Sexo TipoContrato           nombreplan  ...  \
# 5613             0     0    0            A  Cereza Excelso Plus  ...
# 7365            HI    34    F            A         Cafe Excelso  ...
# 7367            NI     1    F            A         Cafe Excelso  ...
# 8912            NY    28    M            F  Cereza Excelso Plus  ...
# 8930            CO    45    F            A  Cereza Excelso Plus  ...
# ...            ...   ...  ...          ...                  ...  ...
# 6463678         CM    77    F            A         AMD Integral  ...
# 6463682         MA    85    F            A         AMD Integral  ...
# 6463684         MA    65    F            A         AMD Integral  ...
# 6463685         MA    67    F            A         AMD Integral  ...
# 6463720         MA    84    F            A         AMD Integral  ...
#
#          P_GrossPtoPag Conteo  TypePaid  Periodo_1  AñoMes_Per  \
# 5613         -1.499000    0.0    Cancel   201612.0         NaN
# 7365          0.152970    1.0   Inforce   201612.0         NaN
# 7367          0.127047    1.0   Inforce   201612.0         NaN
# 8912          0.131750    1.0   Inforce   201612.0         NaN
# 8930          0.084305    1.0   Inforce   201612.0         NaN
# ...                ...    ...       ...        ...         ...
# 6463678       0.046623    1.0   Inforce   202208.0         NaN
# 6463682       0.018527    1.0   Inforce   202208.0         NaN
# 6463684       0.048500    1.0   Inforce   202208.0         NaN
# 6463685       0.048500    1.0   Inforce   202208.0         NaN
# 6463720       0.048500    1.0   Inforce   202208.0         NaN
#
#          NUMERO CONTRATO Carnet  FECHA INI VIGENCIA  FECHA FIN VIGENCIA  \
# 5613                 NaN    NaN                 NaT                 NaT
# 7365                 NaN    NaN                 NaT                 NaT
# 7367                 NaN    NaN                 NaT                 NaT
# 8912                 NaN    NaN                 NaT                 NaT
# 8930                 NaN    NaN                 NaT                 NaT
# ...                  ...    ...                 ...                 ...
# 6463678              NaN    NaN                 NaT                 NaT
# 6463682              NaN    NaN                 NaT                 NaT
# 6463684              NaN    NaN                 NaT                 NaT
# 6463685              NaN    NaN                 NaT                 NaT
# 6463720              NaN    NaN                 NaT                 NaT
#
#          Conteo1
# 5613         NaN
# 7365         NaN
# 7367         NaN
# 8912         NaN
# 8930         NaN
# ...          ...
# 6463678      NaN
# 6463682      NaN
# 6463684      NaN
# 6463685      NaN
# 6463720      NaN
#
# [96977 rows x 24 columns]

# %%
df_1.drop(['AñoMes_Per', 'NUMERO CONTRATO', 'Carnet', 'FECHA INI VIGENCIA', 'FECHA FIN VIGENCIA', 'Conteo1'], axis=1, inplace=True)
df_1.head()
# Out:
#        Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 5613  201701.0 2017-01-01 2017-01-31           55559              0
# 7365  201701.0 2017-01-01 2017-01-31           65148        6514803
# 7367  201701.0 2017-01-01 2017-01-31           65148        6514805
# 8912  201701.0 2017-01-01 2017-01-31           70605        7060505
# 8930  201701.0 2017-01-01 2017-01-31           70653        7065301
#
#      Parentesco  Edad Sexo TipoContrato           nombreplan  CodMatriz  \
# 5613          0     0    0            A  Cereza Excelso Plus       60.0
# 7365         HI    34    F            A         Cafe Excelso      326.0
# 7367         NI     1    F            A         Cafe Excelso      326.0
# 8912         NY    28    M            F  Cereza Excelso Plus     9999.0
# 8930         CO    45    F            A  Cereza Excelso Plus       63.0
#
#       ciudad   Premium  P_NetPtoPag  P_GrossPtoPag  Conteo TypePaid  Periodo_1
# 5613  BOGOTA -1.499000    -1.499000      -1.499000     0.0   Cancel   201612.0
# 7365  BOGOTA  0.152970     0.152970       0.152970     1.0  Inforce   201612.0
# 7367  BOGOTA  0.127047     0.127047       0.127047     1.0  Inforce   201612.0
# 8912  BOGOTA  0.131750     0.131750       0.131750     1.0  Inforce   201612.0
# 8930  BOGOTA  0.084305     0.084305       0.084305     1.0  Inforce   201612.0

# %%
df_ExpFinal = pd.merge(left = df_1, right = df_Exp_Agg, how = 'left',
                       left_on = (['Periodo_1', 'numerocontrato', 'CarnetUsuario']),
                       right_on = (['AñoMes_Per', 'NUMERO CONTRATO', 'Carnet']))

# %%
df_ExpFinal
# Out:
#         Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 0      201701.0 2017-01-01 2017-01-31           55559              0
# 1      201701.0 2017-01-01 2017-01-31           65148        6514803
# 2      201701.0 2017-01-01 2017-01-31           65148        6514805
# 3      201701.0 2017-01-01 2017-01-31           70605        7060505
# 4      201701.0 2017-01-01 2017-01-31           70653        7065301
# ...         ...        ...        ...             ...            ...
# 96972  202209.0 2022-09-01 2022-09-30          451329       45132901
# 96973  202209.0 2022-09-01 2022-09-30          451331       45133101
# 96974  202209.0 2022-09-01 2022-09-30          451333       45133301
# 96975  202209.0 2022-09-01 2022-09-30          451334       45133401
# 96976  202209.0 2022-09-01 2022-09-30          451358       45135801
#
#       Parentesco  Edad Sexo TipoContrato           nombreplan  ...  \
# 0              0     0    0            A  Cereza Excelso Plus  ...
# 1             HI    34    F            A         Cafe Excelso  ...
# 2             NI     1    F            A         Cafe Excelso  ...
# 3             NY    28    M            F  Cereza Excelso Plus  ...
# 4             CO    45    F            A  Cereza Excelso Plus  ...
# ...          ...   ...  ...          ...                  ...  ...
# 96972         CM    77    F            A         AMD Integral  ...
# 96973         MA    85    F            A         AMD Integral  ...
# 96974         MA    65    F            A         AMD Integral  ...
# 96975         MA    67    F            A         AMD Integral  ...
# 96976         MA    84    F            A         AMD Integral  ...
#
#        P_GrossPtoPag Conteo  TypePaid  Periodo_1  AñoMes_Per  NUMERO CONTRATO  \
# 0          -1.499000    0.0    Cancel   201612.0         NaN              NaN
# 1           0.152970    1.0   Inforce   201612.0         NaN              NaN
# 2           0.127047    1.0   Inforce   201612.0         NaN              NaN
# 3           0.131750    1.0   Inforce   201612.0         NaN              NaN
# 4           0.084305    1.0   Inforce   201612.0         NaN              NaN
# ...              ...    ...       ...        ...         ...              ...
# 96972       0.046623    1.0   Inforce   202208.0         NaN              NaN
# 96973       0.018527    1.0   Inforce   202208.0         NaN              NaN
# 96974       0.048500    1.0   Inforce   202208.0         NaN              NaN
# 96975       0.048500    1.0   Inforce   202208.0         NaN              NaN
# 96976       0.048500    1.0   Inforce   202208.0         NaN              NaN
#
#       Carnet  FECHA INI VIGENCIA  FECHA FIN VIGENCIA  Conteo1
# 0        NaN                 NaT                 NaT      NaN
# 1        NaN                 NaT                 NaT      NaN
# 2        NaN                 NaT                 NaT      NaN
# 3        NaN                 NaT                 NaT      NaN
# 4        NaN                 NaT                 NaT      NaN
# ...      ...                 ...                 ...      ...
# 96972    NaN                 NaT                 NaT      NaN
# 96973    NaN                 NaT                 NaT      NaN
# 96974    NaN                 NaT                 NaT      NaN
# 96975    NaN                 NaT                 NaT      NaN
# 96976    NaN                 NaT                 NaT      NaN
#
# [96977 rows x 24 columns]

# %%
df_ExpFinal['FECHA INI VIGENCIA'].isna().sum()
# Out:
# 81526

# %%
df_ExpFinal = df_ExpFinal.reset_index()
df_ExpFinal.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\Exp_PremNoCrux_202209_Valid.txt', sep = ';', encoding = 'utf-8', index = False)

# %% [markdown]
# # Se eliminan los registros sin coherencia en la identificación del carnet y de las fechas de inicio y fin de vigencia

# %%
df_ExpFinal = df_ExpFinal.dropna(subset=['FECHA INI VIGENCIA', 'FECHA FIN VIGENCIA'])
df_ExpFinal['Periodo'].count()
# Out:
# 15451

# %%
df_ExpPreliminary = df_ExpPreliminary.dropna(subset=['FECHA INI VIGENCIA', 'FECHA FIN VIGENCIA'])
df_ExpPreliminary['Periodo'].count()
# Out:
# 6366749

# %%
df_ExpT = pd.concat([df_ExpPreliminary, df_ExpFinal], axis = 0, ignore_index = False, keys = None, sort = False, copy = True)
df_ExpT['Periodo'].count()
# Out:
# 6382200

# %%
df_Valid = df_ExpT.loc[((df_ExpT['TypePaid'] == 'Cancel') | (df_ExpT['TypePaid'] == 'Move_w/oP'))]
df_Valid
# Out:
#         Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 703    201701.0 2017-01-01 2017-01-31           14014        1401401
# 704    201701.0 2017-01-01 2017-01-31           14014        1401402
# 705    201701.0 2017-01-01 2017-01-31           14017        1401702
# 706    201701.0 2017-01-01 2017-01-31           14017        1401704
# 707    201701.0 2017-01-01 2017-01-31           14017        1401708
# ...         ...        ...        ...             ...            ...
# 96654  202209.0 2022-09-01 2022-09-30          448208       44820801
# 96661  202209.0 2022-09-01 2022-09-30          448223       44822301
# 96665  202209.0 2022-09-01 2022-09-30          448264       44826401
# 96666  202209.0 2022-09-01 2022-09-30          448265       44826501
# 96702  202209.0 2022-09-01 2022-09-30          448802       44880201
#
#       Parentesco  Edad Sexo TipoContrato           nombreplan  ...  \
# 703           CM    81    F            C  Cereza Excelso Plus  ...
# 704           MA    84    M            C  Cereza Excelso Plus  ...
# 705           MA    78    F            C         Cafe Excelso  ...
# 706           OT    52    F            C         Cafe Excelso  ...
# 707           OT    41    F            C         Cafe Excelso  ...
# ...          ...   ...  ...          ...                  ...  ...
# 96654         CT    23    F            F            Azul Plus  ...
# 96661         CT    32    F            F         Cafe Express  ...
# 96665         CT    48    F            A         Cafe Excelso  ...
# 96666         HI     0    M            F         Cafe Express  ...
# 96702         HI    33    F            A         Celeste Plus  ...
#
#        P_GrossPtoPag Conteo   TypePaid  Periodo_1  AñoMes_Per  \
# 703              0.0    0.0  Move_w/oP   201612.0    201701.0
# 704              0.0    0.0  Move_w/oP   201612.0    201701.0
# 705              0.0    0.0  Move_w/oP   201612.0    201701.0
# 706              0.0    0.0  Move_w/oP   201612.0    201701.0
# 707              0.0    0.0  Move_w/oP   201612.0    201701.0
# ...              ...    ...        ...        ...         ...
# 96654            0.0    0.0  Move_w/oP   202208.0    202208.0
# 96661            0.0    0.0  Move_w/oP   202208.0    202208.0
# 96665            0.0    0.0  Move_w/oP   202208.0    202208.0
# 96666            0.0    0.0  Move_w/oP   202208.0    202208.0
# 96702            0.0    0.0  Move_w/oP   202208.0    202208.0
#
#        NUMERO CONTRATO      Carnet  FECHA INI VIGENCIA  FECHA FIN VIGENCIA  \
# 703            14014.0   1401401.0          2016-01-01          2016-12-31
# 704            14014.0   1401402.0          2016-01-01          2016-12-31
# 705            14017.0   1401702.0          2016-01-01          2016-12-31
# 706            14017.0   1401704.0          2016-01-01          2016-12-31
# 707            14017.0   1401708.0          2016-01-01          2016-12-31
# ...                ...         ...                 ...                 ...
# 96654         448208.0  44820801.0          2022-06-30          2023-06-29
# 96661         448223.0  44822301.0          2022-06-30          2023-06-29
# 96665         448264.0  44826401.0          2022-05-31          2023-05-30
# 96666         448265.0  44826501.0          2022-06-30          2023-06-29
# 96702         448802.0  44880201.0          2022-07-31          2023-07-30
#
#        Conteo1
# 703        1.0
# 704        1.0
# 705        1.0
# 706        1.0
# 707        1.0
# ...        ...
# 96654      1.0
# 96661      1.0
# 96665      1.0
# 96666      1.0
# 96702      1.0
#
# [42133 rows x 24 columns]

# %%
#df_Valid = df_Valid.reset_index()
#df_Valid.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\Exp_PremNeg_202209_Valid.txt', sep = ';', encoding = 'utf-8', index = False)

# %%
# Se valida

# %%
conditions = [
    (df_ExpT['FECHA INI VIGENCIA'] <= df_ExpT['FecIni_Per']) & (df_ExpT['FECHA FIN VIGENCIA'] >= df_ExpT['FecFin_Per']),
    (df_ExpT['FECHA INI VIGENCIA'] <= df_ExpT['FecIni_Per']) & (df_ExpT['FECHA FIN VIGENCIA'] >= df_ExpT['FecIni_Per']) & (df_ExpT['FECHA FIN VIGENCIA'] <= df_ExpT['FecFin_Per']),
    (df_ExpT['FECHA INI VIGENCIA'] >= df_ExpT['FecIni_Per']) & (df_ExpT['FECHA INI VIGENCIA'] <= df_ExpT['FecFin_Per']) & (df_ExpT['FECHA FIN VIGENCIA'] >= df_ExpT['FecFin_Per']),
    (df_ExpT['FECHA INI VIGENCIA'] >= df_ExpT['FecIni_Per']) & (df_ExpT['FECHA FIN VIGENCIA'] <= df_ExpT['FecFin_Per']),
    (df_ExpT['FECHA FIN VIGENCIA'] < df_ExpT['FecIni_Per']),
    (df_ExpT['FECHA INI VIGENCIA'] > df_ExpT['FecFin_Per'])
]
values = ['1', '2', '3', '4', '5', '6']
df_ExpT['Range_0'] = np.select(conditions, values)
df_ExpT.head()
# Out:
#     Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario Parentesco  \
# 0  201701.0 2017-01-01 2017-01-31             307          30701         CT
# 1  201701.0 2017-01-01 2017-01-31             307          30702         CO
# 2  201701.0 2017-01-01 2017-01-31             307          30703         HI
# 3  201701.0 2017-01-01 2017-01-31             307          30706         OH
# 4  201701.0 2017-01-01 2017-01-31             329          32901         CT
#
#    Edad Sexo TipoContrato    nombreplan  ...  Conteo TypePaid  Periodo_1  \
# 0    62    M            F  Cafe Excelso  ...     1.0  Inforce   201612.0
# 1    57    F            F  Cafe Excelso  ...     1.0  Inforce   201612.0
# 2    26    F            F  Cafe Excelso  ...     1.0  Inforce   201612.0
# 3    22    F            F  Cafe Excelso  ...     1.0  Inforce   201612.0
# 4    51    F            C  Cafe Excelso  ...     1.0  Inforce   201612.0
#
#    AñoMes_Per  NUMERO CONTRATO   Carnet FECHA INI VIGENCIA  \
# 0    201701.0            307.0  30701.0         2017-01-01
# 1    201701.0            307.0  30702.0         2017-01-01
# 2    201701.0            307.0  30703.0         2017-01-01
# 3    201701.0            307.0  30706.0         2017-01-01
# 4    201701.0            329.0  32901.0         2017-01-01
#
#    FECHA FIN VIGENCIA  Conteo1  Range_0
# 0          2017-12-31      1.0        1
# 1          2017-12-31      1.0        1
# 2          2017-12-31      1.0        1
# 3          2017-12-31      1.0        1
# 4          2017-12-31      1.0        1
#
# [5 rows x 25 columns]

# %%
def Exposure(df_ExpT):
    if (df_ExpT['Range_0'] == '1'):
        return abs((df_ExpT['FecFin_Per'] - df_ExpT['FecIni_Per']).days + 1) / 30.4375
    elif (df_ExpT['Range_0'] == '2'):
        return abs((df_ExpT['FECHA FIN VIGENCIA'] - df_ExpT['FecIni_Per']).days + 1) / 30.4375 
    elif (df_ExpT['Range_0'] == '3'):
        return abs((df_ExpT['FecFin_Per'] - df_ExpT['FECHA INI VIGENCIA']).days + 1) / 30.4375
    elif (df_ExpT['Range_0'] == '4'):
        return abs((df_ExpT['FECHA FIN VIGENCIA'] - df_ExpT['FECHA INI VIGENCIA']).days + 1) / 30.4375
    elif (df_ExpT['Range_0'] == '5'):
        return (0)
    elif (df_ExpT['Range_0'] == '6'):
        return (0)
df_ExpT['Exposure'] = df_ExpT.apply(Exposure, axis = 1)

# %%
df_ExpT
# Out:
#         Periodo FecIni_Per FecFin_Per  numerocontrato  CarnetUsuario  \
# 0      201701.0 2017-01-01 2017-01-31             307          30701
# 1      201701.0 2017-01-01 2017-01-31             307          30702
# 2      201701.0 2017-01-01 2017-01-31             307          30703
# 3      201701.0 2017-01-01 2017-01-31             307          30706
# 4      201701.0 2017-01-01 2017-01-31             329          32901
# ...         ...        ...        ...             ...            ...
# 96654  202209.0 2022-09-01 2022-09-30          448208       44820801
# 96661  202209.0 2022-09-01 2022-09-30          448223       44822301
# 96665  202209.0 2022-09-01 2022-09-30          448264       44826401
# 96666  202209.0 2022-09-01 2022-09-30          448265       44826501
# 96702  202209.0 2022-09-01 2022-09-30          448802       44880201
#
#       Parentesco  Edad Sexo TipoContrato    nombreplan  ...   TypePaid  \
# 0             CT    62    M            F  Cafe Excelso  ...    Inforce
# 1             CO    57    F            F  Cafe Excelso  ...    Inforce
# 2             HI    26    F            F  Cafe Excelso  ...    Inforce
# 3             OH    22    F            F  Cafe Excelso  ...    Inforce
# 4             CT    51    F            C  Cafe Excelso  ...    Inforce
# ...          ...   ...  ...          ...           ...  ...        ...
# 96654         CT    23    F            F     Azul Plus  ...  Move_w/oP
# 96661         CT    32    F            F  Cafe Express  ...  Move_w/oP
# 96665         CT    48    F            A  Cafe Excelso  ...  Move_w/oP
# 96666         HI     0    M            F  Cafe Express  ...  Move_w/oP
# 96702         HI    33    F            A  Celeste Plus  ...  Move_w/oP
#
#       Periodo_1  AñoMes_Per  NUMERO CONTRATO      Carnet  FECHA INI VIGENCIA  \
# 0      201612.0    201701.0            307.0     30701.0          2017-01-01
# 1      201612.0    201701.0            307.0     30702.0          2017-01-01
# 2      201612.0    201701.0            307.0     30703.0          2017-01-01
# 3      201612.0    201701.0            307.0     30706.0          2017-01-01
# 4      201612.0    201701.0            329.0     32901.0          2017-01-01
# ...         ...         ...              ...         ...                 ...
# 96654  202208.0    202208.0         448208.0  44820801.0          2022-06-30
# 96661  202208.0    202208.0         448223.0  44822301.0          2022-06-30
# 96665  202208.0    202208.0         448264.0  44826401.0          2022-05-31
# 96666  202208.0    202208.0         448265.0  44826501.0          2022-06-30
# 96702  202208.0    202208.0         448802.0  44880201.0          2022-07-31
#
#       FECHA FIN VIGENCIA  Conteo1  Range_0  Exposure
# 0             2017-12-31      1.0        1  1.018480
# 1             2017-12-31      1.0        1  1.018480
# 2             2017-12-31      1.0        1  1.018480
# 3             2017-12-31      1.0        1  1.018480
# 4             2017-12-31      1.0        1  1.018480
# ...                  ...      ...      ...       ...
# 96654         2023-06-29      1.0        1  0.985626
# 96661         2023-06-29      1.0        1  0.985626
# 96665         2023-05-30      1.0        1  0.985626
# 96666         2023-06-29      1.0        1  0.985626
# 96702         2023-07-30      1.0        1  0.985626
#
# [6382200 rows x 26 columns]

# %%
a, b, c, d = df_ExpT['Exposure'].sum(), df_ExpT['Exposure'].mean(), df_ExpT['Exposure'].min(), df_ExpT['Exposure'].max()
a, b, c, d
# Out:
# (5950319.474332647, 0.9323304619354452, 0.0, 1.0184804928131417)

# %%
df_ExpT.loc[df_ExpT['TypePaid'] == 'Inforce', 'Mult'] = 1
df_ExpT.loc[df_ExpT['TypePaid'] != 'Inforce', 'Mult'] = 0

# %%
df_ExpT['Exp_F'] = df_ExpT['Mult'] * df_ExpT['Exposure']

# %%
a, b, c, d = df_ExpT['Exp_F'].sum(), df_ExpT['Exp_F'].mean(), df_ExpT['Exp_F'].min(), df_ExpT['Exp_F'].max()
a, b, c, d
# Out:
# (5927583.967145795, 0.9287681312052715, 0.0, 1.0184804928131417)

# %%
#df_ExpT = df_ExpT.reset_index()
#df_ExpT.to_csv('D:\RODRIY21\A_DB\DB_Usuarios\DB_Exposure\Results_202211\Exp_2017-202209.txt', sep = ';', encoding = 'utf-8', index = False)
